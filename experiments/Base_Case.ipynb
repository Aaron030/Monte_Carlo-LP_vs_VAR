# %% [markdown]
# Set up of the simulation

# %%
# import packages
from mcsim.estimators import estimate_lp_irf, estimate_var_irf
from mcsim.simulation import MCConfig, run
from tqdm import tqdm

# Define horizons etc
T = [100, 200, 240, 500]
H = [x for x in range(24)]

# %%
cfg = MCConfig(
    n_reps=1000,
    T=240,
    horizon=20,
    seed=20260527,
    n_jobs=-1,
    estimators={
        "VAR": estimate_var_irf,
        "LP": estimate_lp_irf,
    },
)
dgp_spec = None  # TODO: define
results = run(dgp_spec, cfg)
print(results)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[2], line 13
#       1 cfg = MCConfig(
#       2     n_reps=1000,
#       3     T=240,
#    (...)
#      10     },
#      11 )
#      12 dgp_spec = None  # TODO: define
# ---> 13 results = run(dgp_spec, cfg)
#      14 print(results)
#
# File ~/GitHub/MonteCarloSeminar/src/mcsim/simulation.py:29, in run(dgp_spec, cfg)
#      27 def run(dgp_spec, cfg: MCConfig) -> dict[str, np.ndarray]:
#      28     """Run Monte Carlo. Returns dict of stacked IRFs per estimator. To be implemented."""
# ---> 29     raise NotImplementedError
#
# NotImplementedError:
